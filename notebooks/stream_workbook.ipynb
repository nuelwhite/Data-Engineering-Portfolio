# %% [markdown]
# ## workbook for spark streaming logic
#
# Spark Structured Stream processing works different than the regular batch processing, because everything is happening in real-time. Transformations are the same, but the configurations for a spark stream processing is not like that of the regular processing
#
# During batch processing, you can choose to infer schema when you are reading data from a csv or any source, although recommended that you create a schema. But with stream processing you need to need create these schemas.
#
# There are different configurations that will be done.

# %%
from pyspark.sql import SparkSession

# %%
# initialize spark

spark = SparkSession.builder.appName('Ecommerce_events_payload_streaming').getOrCreate()

# %% [markdown]
# For now I want to have a feel of the dataset I generated, create a framework for subsequent streaming

# %%
input_file = 'spark_streaming_project/events_data/event_data_00001.csv'

# %%
df = spark.read.csv(input_file, inferSchema=True, header=True)

# %%
df.printSchema()
# Out:
# root
#  |-- event_id: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- product_price: double (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- order_id: string (nullable = true)
#  |-- cart_value: double (nullable = true)
#  |-- discount_applied: boolean (nullable = true)
#  |-- shipping_method: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- age_group: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- loyalty_member: boolean (nullable = true)
#  |-- device: string (nullable = true)
#  |-- operating_system: string (nullable = true)
#  |-- browser: string (nullable = true)
#  |-- ip_address: string (nullable = true)
# ...

# %% [markdown]
# Based on this schema, let's create a schema for streamming using StructType

# %%
from pyspark.sql.types import StructType, StructField, StringType, FloatType, TimestampType, IntegerType, BooleanType

# %%
streaming_schema = StructType(
    [
        StructField('event_id', StringType(), True),
        StructField('timestamp', TimestampType(), True),
        StructField('event_type', StringType(), True),
        StructField('user_id', StringType(), True),
        StructField('session_id', StringType(), True),
        StructField('product_id', StringType(), True),
        StructField('product_category', StringType(), True),
        StructField('product_price', FloatType(), True),
        StructField('quantity', IntegerType(), True),
        StructField('order_id', StringType(), True),
        StructField('cart_value', FloatType(), True),
        StructField('discount_applied', BooleanType(), True),
        StructField('shipping_method', StringType(), True),
        StructField('payment_method', StringType(), True),
        StructField('location', StringType(), True),
        StructField('age_group', StringType(), True),
        StructField('gender', StringType(), True),
        StructField('loyalty_member', BooleanType(), True),
        StructField('device', StringType(), True),
        StructField('operating_system', StringType(), True),
        StructField('browser', StringType(), True),
        StructField('ip_address', StringType(), True),
        StructField('latency_ms', IntegerType(), True),
        StructField('utm_source', StringType(), True),
        StructField('utm_campaign', StringType(), True),
        StructField('page_url', StringType(), True),
        StructField('referrer_url', StringType(), True),
    ]
)

# %%
df.select('*').head()
# Out:
# Row(event_id='78422f26-1952-4ab8-90aa-41aec4bdd711', timestamp=datetime.datetime(2025, 9, 12, 14, 28, 57), event_type='view', user_id='user_86', session_id='session_970', product_id='prod_129', product_category='Sports', product_price=169.83, quantity=0, order_id=None, cart_value=None, discount_applied=False, shipping_method=None, payment_method=None, location='Tamale', age_group='18-24', gender='Male', loyalty_member=False, device='Desktop', operating_system='Windows', browser='Safari', ip_address='53.55.146.62', latency_ms=311, utm_source='google', utm_campaign='google_campaign', page_url='checkout_page', referrer_url='https://www.other.com')
